# %%
import numpy as np
import pandas as pd
import gensim
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
import json
from nltk import RegexpTokenizer
import time
from keras.preprocessing.text import Tokenizer
import random
import multiprocessing
from nltk import RegexpTokenizer
import copy
import pickle
multiprocessing.cpu_count()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_path = '/content/drive/My Drive/ImageCap/flickr30k_images/'
text_path = '/content/drive/My Drive/ImageCap/captions.csv'

# %%
df = pd.read_csv(text_path ,delimiter='|', skipinitialspace=True) #in this csv, | is being used as delimiter

# %%
groups = [b for a,b in df.groupby('image_name')] #Seperating rows into groups as per image name
random.shuffle(groups) #applying shuffle operation group-wise
df = pd.concat(groups).reset_index(drop=True)

# %%
image_name_list = list(set(df['image_name'])) #obtaining unique instance name of each image
image_path_list = list(map(lambda arg: image_path + arg, image_name_list))

# %%
df.loc[0]
# Out:
# image_name                                           3296226598.jpg
# comment_number                                                    0
# comment           A man in a black leather jacket walks next to ...
# Name: 0, dtype: object

# %%
df['comment'] = df['comment'].apply(lambda arg: '<start> ' + str(arg) + ' <end>') #putting start and end tokens

# %%
df.loc[0]['comment']
# Out:
# '<start> A man in a black leather jacket walks next to a white brick building in a big city . <end>'

# %%
tokenizer = RegexpTokenizer(r'\w+|<start>|<end>') #tokenizing using only alphanumeric tokens and start, end tokens
df['tokens'] = df['comment'].apply(tokenizer.tokenize)

# %%
df.loc[0]['tokens']
# Out:
# ['<start>',
#  'A',
#  'man',
#  'in',
#  'a',
#  'black',
#  'leather',
#  'jacket',
#  'walks',
#  'next',
#  'to',
#  'a',
#  'white',
#  'brick',
#  'building',
#  'in',
#  'a',
#  'big',
#  'city',
#  '<end>']

# %%
#Finding max length for padding
len_ = df['tokens'].apply(lambda arg: len(arg))
max_len = max(len_)

# %%
#padding to max_len
def pad(arg):
  len_ = len(arg)
  len_ = max_len - len_
  lst = copy.deepcopy(arg)
  for i in np.arange(0,len_):
    lst.append('_')
  return lst

df['tokens_pad'] = df['tokens'].apply(pad)

# %%
df.loc[0]['tokens_pad']
# Out:
# ['<start>',
#  'A',
#  'man',
#  'in',
#  'a',
#  'black',
#  'leather',
#  'jacket',
#  'walks',
#  'next',
#  'to',
#  'a',
#  'white',
#  'brick',
#  'building',
#  'in',
#  'a',
#  'big',
#  'city',
#  '<end>',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_',
#  '_']

# %%
#Training our custom word2vec model
t=time.time()
obj_w2v=Word2Vec(sentences=df['tokens'],min_count=1,window=2,size=300,sample=6e-5, alpha=0.03, min_alpha=0.0007, negative=20,workers=2,iter=30)
print(time.time()-t)
# Out:
# 131.58676886558533

# %%
#Loading Google's pretrainind w2v model
t=time.time()
word2vec_path = "/content/drive/My Drive/ImageCap/GoogleNews-vectors-negative300.bin.gz"
w2v_g = gensim.models.KeyedVectors.load_word2vec_format(word2vec_path, binary=True)
print(time.time()-t)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 144.9913194179535

# %%
#updating our local model's vocab with google's w2v's vocab
t=time.time()
obj_w2v.build_vocab([list(w2v_g.vocab.keys())],update=True)
print(time.time()-t)
# Out:
# 999.7349133491516

# %%
t=time.time()
obj_w2v.intersect_word2vec_format('/content/drive/My Drive/ImageCap/GoogleNews-vectors-negative300.bin.gz',lockf=1.0, binary=True)
#this function will look for words common in our vocab 
#and in google's vocab and change the weight of such words to that in google's weight vector. 
#Here we have set lockf=1 so that in further training weights of all the
#words are optimized

print(time.time()-t)
# Out:
# 170.2057385444641

# %%
t=time.time()
obj_w2v.train(df['tokens'],total_examples=len(df),epochs=obj_w2v.iter)#we are training again so as to get weights adjusted
print(time.time()-t)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# 627.3765051364899

# %%
obj_w2v.save('/content/drive/My Drive/ImageCap/w2v_imageCap.kv') #This will save entire model

# %%
obj_w2v.wv.save_word2vec_format('/content/drive/My Drive/ImageCap/w2v_imageCap.bin', binary=True) #This will only save matrix / vocab of model

# %%
word2vec = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/My Drive/ImageCap/w2v_imageCap.bin', binary=True,unicode_errors='ignore')

# %%
#Now we will create a new vocab of most used tokens and then later map them to their w2v embeddings
vec=Tokenizer()
vec.fit_on_texts(df['tokens'])
l=len((vec.word_index))
print(l)
print((vec.word_index))#dictionary
# Out:
# 18289
# {'a': 1, '<start>': 2, '<end>': 3, 'in': 4, 'the': 5, 'on': 6, 'and': 7, 'man': 8, 'is': 9, 'of': 10, 'with': 11, 'woman': 12, 'two': 13, 'are': 14, 'to': 15, 'people': 16, 'at': 17, 'an': 18, 'wearing': 19, 'shirt': 20, 'white': 21, 'young': 22, 'black': 23, 'while': 24, 'his': 25, 'blue': 26, 'red': 27, 'girl': 28, 'sitting': 29, 'men': 30, 'boy': 31, 'standing': 32, 'dog': 33, 'playing': 34, 'street': 35, 'group': 36, 'down': 37, 'front': 38, 'her': 39, 'walking': 40, 'holding': 41, 'one': 42, 'water': 43, 'three': 44, 'by': 45, 'women': 46, 'green': 47, 'up': 48, 'looking': 49, 'child': 50, 'as': 51, 'for': 52, 'little': 53, 'large': 54, 'outside': 55, 'brown': 56, 'yellow': 57, 'person': 58, 'children': 59, 'through': 60, 'hat': 61, 'from': 62, 'their': 63, 'other': 64, 'ball': 65, 'small': 66, 'next': 67, 'into': 68, 'over': 69, 'some': 70, 'dressed': 71, 'out': 72, 'another': 73, 'running': 74, 'building': 75, 'jacket': 76, 'riding': 77, 'around': 78, 'orange': 79, 'near': 80, 'field': 81, 'crowd': 82, 'stands': 83, 'beach': 84, 'background': 85, 'pink': 86, 'behind': 87, 'sidewalk': 88, 'hair': 89, 'jumping': 90, 'table': 91, 'girls': 92, 'snow': 93, 'sits': 94, 'grass': 95, 'bike': 96, 'that': 97, 'camera': 98, 'looks': 99, 'top': 100, 'air': 101, 'asian': 102, 'dogs': 103, 's': 104, 'stand': 105, 'wall': 106, 'city': 107, 'player': 108, 'older': 109, 'off': 110, 'four': 111, 'has': 112, 'gray': 113, 'working': 114, 'soccer': 115, 'blond': 116, 'dress': 117, 'something': 118, 'it': 119, 'several': 120, 'talking': 121, 'shorts': 122, 'park': 123, 'lady': 124, 'him': 125, 'guitar': 126, 'picture': 127, 'walks': 128, 'pants': 129, 'boys': 130, 'hand': 131, 'smiling': 132, 'jeans': 133, 'plays': 134, 'play': 135, 'along': 136, 'dark': 137, 'road': 138, 'together': 139, 'carrying': 140, 'game': 141, 'holds': 142, 'car': 143, 'food': 144, 'bench': 145, 'them': 146, 'side': 147, 'walk': 148, 'long': 149, 'face': 150, 'baby': 151, 'there': 152, 'old': 153, 'head': 154, 'glasses': 155, 'stage': 156, 'sit': 157, 'back': 158, 'bicycle': 159, 't': 160, 'tree': 161, 'hands': 162, 'taking': 163, 'doing': 164, 'pool': 165, 'watching': 166, 'rock': 167, 'male': 168, 'guy': 169, 'each': 170, 'couple': 171, 'baseball': 172, 'area': 173, 'ground': 174, 'who': 175, 'dirt': 176, 'he': 177, 'female': 178, 'middle': 179, 'being': 180, 'race': 181, 'striped': 182, 'boat': 183, 'day': 184, 'performing': 185, 'jumps': 186, 'mouth': 187, 'look': 188, 'construction': 189, 'suit': 190, 'coat': 191, 'purple': 192, 'room': 193, 'across': 194, 'many': 195, 'sunglasses': 196, 'eating': 197, 'football': 198, 'under': 199, 'sign': 200, 'horse': 201, 'runs': 202, 'band': 203, 'kids': 204, 'haired': 205, 'sand': 206, 'using': 207, 'uniform': 208, 'microphone': 209, 'helmet': 210, 'reading': 211, 'its': 212, 'tennis': 213, 'or': 214, 'watch': 215, 'players': 216, 'workers': 217, 'be': 218, 'store': 219, 'toy': 220, 'watches': 221, 'floor': 222, 'all': 223, 'shirts': 224, 'wooden': 225, 'rides': 226, 'against': 227, 'mountain': 228, 'this': 229, 'train': 230, 'ocean': 231, 'window': 232, 'basketball': 233, 'during': 234, 'cap': 235, 'about': 236, 'covered': 237, 'work': 238, 'chair': 239, 'dancing': 240, 'elderly': 241, 'busy': 242, 'clothing': 243, 'bag': 244, 'team': 245, 'climbing': 246, 'waiting': 247, 'getting': 248, 'having': 249, 'trees': 250, 'swimming': 251, 'outdoor': 252, 'past': 253, 'they': 254, 'restaurant': 255, 'colorful': 256, 'making': 257, 'posing': 258, 'inside': 259, 'singing': 260, 'trying': 261, 'skateboard': 262, 'fence': 263, 'five': 264, 'tan': 265, 'light': 266, 'high': 267, 'line': 268, 'market': 269, 'brick': 270, 'ice': 271, 'she': 272, 'very': 273, 'hats': 274, 'big': 275, 'ride': 276, 'towards': 277, 'colored': 278, 'sweater': 279, 'someone': 280, 'beside': 281, 'lake': 282, 'jump': 283, 'motorcycle': 284, 'cart': 285, 'truck': 286, 'hill': 287, 'open': 288, 'surrounded': 289, 'bright': 290, 'cellphone': 291, 'grassy': 292,  ...

# %%
#Here we are generating a matrix that contains embedding of each word in our vocabulary
r=0
M=(np.zeros((l,300)))
#d=pd.DataFrame()
for el in vec.word_index:
  try:
    M[r,:]=word2vec[str(el)]#put entire word vector for el in rth row
  except:
    M[r,:]=np.zeros((1,300)) #in case of an unknown word, simply put zero vector
    print('error for ',' ',el)
  #d=d.append(pd.DataFrame(data={'row':[r], 'word': [el]}))# storing the mapping of row to word
  r=r+1

print(r)
# Out:
# error for    jenga
# error for    squarepants
# error for    lynyrd
# error for    skynyrd
# error for    heineken
# error for    quiznos
# error for    odeon
# error for    hollister
# error for    vuitton
# error for    aladdin
# error for    penske
# error for    atvs
# error for    springsteen
# error for    nesquik
# error for    groucho
# error for    kawasaki
# error for    nypd
# error for    atms
# error for    starbuck
# error for    giorgio
# error for    stonehurst
# error for    usain
# error for    citroen
# error for    sallie
# error for    nescafe
# error for    shoegasm
# error for    hendrix
# error for    gump
# error for    drayton
# error for    sugarland
# error for    rockettes
# error for    makerbot
# error for    lexmark
# error for    exxxotica
# error for    dhl
# error for    ginobili
# error for    sva
# error for    theatre
# error for    khera
# error for    hartman
# error for    brigada
# error for    wwii
# error for    isuzu
# error for    altima
# error for    tabacchi
# error for    bleecker
# error for    tropicana
# error for    olvido
# error for    jagermeister
# error for    elizabethan
# error for    swiffer
# error for    dmc
# error for    tiananmen
# error for    centre
# error for    lavigne
# error for    sbarro
# error for    sxswo
# error for    boja
# error for    penzance
# error for    applebee
# error for    infineon
# error for    carlsberg
# error for    astroland
# error for    tehelka
# error for    lyppens
# error for    schipper
# error for    teva
# error for    angele
# error for    hedley
# error for    carnegie
# error for    gonzaga
# error for    spalding
# error for    audrey
# error for    hepburn
# error for    athena
# error for    geico
# error for    ouro
# error for    parkinsons
# error for    greenbay
# error for    davison
# error for    fidel
# error for    eastpak
# error for    acura
# error for    dipaola
# error for    ducati
# error for    triomphe
# error for    exersaucer
# error for    minh
# error for    perla
# error for    yongsan
# error for    znocob
# error for    koninck
# error for    mariale
# error for    carhartt
# error for    aeropostale
# error for    bronislaw
# error for    komorowski
# error for    miradore
# error for    delwood
# error for    roppolo
# error for    credito
# error for    coors
# error for    nikes
# error for    gnc
# error for    smu
# error for    gsu
# error for    madagascar
# error for    filosofie
# error for    maruga
# error for    gidday
# error for    artisti
# error for    nueske
# error for    huppe
# error for    orhtophonie
# error for    qantas
# error for    c103
# error for    stanmore
# error for    salvar
# error for    planeta
# error for    isaf
# error for    thefaceshop
# error for    conagra
# error for    hutchesons
# error for    liebherr
# error for    utep
# error for    rvs
# error for    powerade
# error for    lightyear
# error for    mandita
# error for    vira
# error for    virou
# error for    paddington
# error for    rabobank
# error for    coldtowne
# error for    nathalie
# error for    roxx
# error for    mongol
# error for    gelados
# error for    ghandi
# error for    ovodafone
# error for    longchamp
# error for    absoluteily
# error for    estacione
# error for    nava
# error for    chorriada
# error for    guevera
# error for    psyduck
# error for    leesville
# error for    carhart
# error for    gogh
# error for    gokart
# error for    dorthy
# error for    aquafina
# error for    urkle
# error for    seiko
# error for    coelho
# error for    mondesi
# error for    sillhouttes
# error for    neude
# error for    cofain
# error for    kingsworth
# error for    pescaderia
# error for    remax
# error for    pleople
# error for    ypoung
# error for    mayan
# error for    unexisting
# error for    galina
# error for    inga
# error for    craftslady
# error for    schwinn
# error for    kilburn
# error for    rubbermaid
# error for    heineke
# error for    kirin
# error for    glaad
# error for    farris
# error for    prave
# error for    averill
# error for    furby
# error for    oktoberfest
# error for    przemek
# error for    ivars
# error for    bakersfield
# error for    bismarckstrabe
# error for    sharpley
# error for    twho
# error for    rodderick
# error for    scotsman
# error for    tehse
# error for    krueger
# error for    nutrilite
# error for    karlova
# error for    migros
# error for    spfd
# error for    eyrovia
# error for    airgame
# error for    jouez
# error for    tuscany
# error for    buzzcock
# error for    rotc
# error for    egytian
# error for    bienvenus
# error for    salliemae
# error for    ambuc
# error for    tulowitzki
# error for    linet
# error for    afican
# error for    brenmark
# error for    walgreen
# error for    izod
# error for    parlour
# error for    hdr
# error for    fadaw
# error for    tajdaw
# error for    dahlak
# error for    smirnoff
# error for    vespas
# error for    catan
# error for    monsterbowl
# error for    nugent
# error for    sevilla
# error for    iove
# error for    stampen
# error for    crazi
# error for    osbourne
# error for    artois
# error for    dsw
# error for    burnese
# error for    clydesdales
# error for    kenji
# error for    vaggi
# error for    stratocaster
# error for    u7
# error for    wilmersdorf
# error for    strasse
# error for    kuthhoop
# error for    gubbängen
# error for    buckingham
# error for    izabella
# error for    gkicks
# error for    chickenfoot
# error for    moseride
# error for    gregoire
# error for    weirmeiner
# error for    constructionbike
# error for    stephanopoulos
# error for    maralis
# error for    pnc
# error for    dupar
# error for    goucho
# error for    dlp
# error for    ravins
# error for    davey
# error for    winehouse
# error for    hoyt
# error for    mardis
# error for    mavic
# error for    nagoya
# error for    animaniacs
# error for    bergwacht
# error for    krugt
# error for    judea
# error for    pemex
# error for    hawkeyes
# error for    primor
# error for    abubakar
# error for    loewe
# error for    kildare
# error for    gdsd
# error for    gontaga
# error for    politie
# error for    polotie
# error for    suecia
# error for    zchtv
# error for    wilbert
# error for    baskin
# error for    yuengling
# error for    refworkss
# error for    batwoman
# error for    glamwiki
# error for    beno
# error for    riwal
# error for    vhj
# error for    welchs
# error for    bangrak
# error for    easta
# error for    ryanair
# error for    wikimedia
# error for    zuccherberg
# error for    freemont
# error for    petronas
# error for    hammerstein
# error for    pyranha
# error for    gruta
# error for    trafalgar
# error for    hannukah
# error for    casque
# error for    obligatoire
# error for    carcassonne
# error for    abney
# error for    shelton
# error for    volkswagon
# error for    tannehill
# error for    monterrey
# error for    bsr
# error for    lyrica
# error for    meuter
# error for    abarrotes
# error for    chrismas
# error for    ellery
# error for    spaulding
# error for    faustus
# error for    vfw
# error for    harly
# error for    camelbak
# error for    koffee
# error for    polizes
# error for    deveraux
# error for    kimora
# error for    krunch
# error for    geospec
# error for    centerprise
# error for    eik
# error for    klaus
# error for    dobos
# error for    hanley
# error for    cuomo
# error for    phillie
# error for    xylophonists
# error for    fawkes
# error for    pikesville
# error for    espania
# error for    mastif
# error for    laperla
# error for    recked
# error for    hodo
# error for    lillian
# error for    l6h
# error for    wiggum
# error for    luciano
# error for    tgi
# error for    excalibur
# error for    rottingham
# error for    cyfd
# error for    twome
# error for    beatermix
# error for    conna
# error for    espana
# error for    skyrim
# error for    narvesen
# error for    zales
# error for    connah
# error for    raley
# error for    carnhart
# error for    weimeraners
# error for    carnoustie
# error for    salyo
# error for    museumsbutikken
# error for    lille
# error for    caviler
# error for    obamacondoms
# error for    bisuter
# error for    bolsos
# error for    driggs
# error for    solei
# error for    palomitas
# error for    barret
# error for    sabrett
# error for    nathans
# error for    ywca
# error for    dasani
# error for    sysco
# error for    bolivian
# error for    davonik
# error for    nastavowich
# error for    batiment
# error for    lmmvsd
# error for    effie
# error for    perrier
# error for    hmong
# error for    hobophobia
# error for    mariache
# error for    wagar
# error for    etowah
# error for    eloin
# error for    ferrell
# error for    connett
# error for    ossian
# error for    tecate
# error for    merrell
# error for    zaras
# error for    vally
# error for    chileans
# error for    exuma
# error for    wheelpower
# error for    skimply
# error for    cuido
# error for    weezer
# error for    kayacker
# error for    kfbk
# error for    yukla
# error for    livingstone
# error for    rnli
# error for    stai
# error for    guardano
# error for    pavitmento
# error for    rawlings
# error for    aztec
# error for    modell
# error for    sylvester
# error for    stallone
# error for    icee
# error for    swac
# error for    halpern
# error for    genpac
# error for    joao
# error for    edwardo
# error for    alvarado
# error for    gladstone
# error for    gillette
# error for    mohegan
# error for    whatcom
# error for    cariboos
# error for    leppard
# error for    collen
# error for    meijer
# error for    cki
# error for    skirvin
# error for    mahmoud
# error for    ahmadinejad
# error for    tyrolean
# error for    dupont
# error for    luca
# error for    kinshasa
# error for    garros
# error for    kimmel
# error for    neptuno
# error for    rachofsky
# error for    fransisco
# error for    ruiz
# error for    yumyumbowls
# error for    tambor
# error for    aveda
# error for    dredd
# error for    benatar
# error for    poust
# error for    hermia
# error for    prology
# error for    bykuwski
# error for    bilbo
# error for    baggins
# error for    peet
# error for    violoncelli
# error for    melky
# error for    cabrera
# error for    jemima
# error for    alessi
# error for    triuneo
# error for    bellingham
# error for    youngle
# error for    tartuffe
# error for    fossar
# error for    moreres
# error for    barnsdall
# error for    mutltiple
# error for    joplin
# error for    machu
# error for    picchu
# error for    stationnement
# error for    dotre
# error for    piza
# error for    tipton
# error for    septu
# error for    covent
# error for    aquos
# error for    dalhausser
# error for    utiah
# error for    gondolieri
# error for    cyranka
# error for    coldwell
# error for    rammstein
# error for    plne
# error for    elisabeth
# error for    knotts
# error for    marquette
# error for    tubeline
# error for    potao
# error for    harrod
# error for    kennington
# error for    maritimo
# error for    chopin
# error for    landscope
# error for    kaitlin
# error for    kaplans
# error for    cristy
# error for    hyndland
# error for    metlife
# error for    holmgren
# error for    seahawkss
# error for    conococo
# error for    goctawek
# error for    debenhams
# error for    jermaine
# error for    concords
# error for    casterol
# error for    johannesburg
# error for    christmastime
# error for    otis
# error for    oreal
# error for    flyre
# error for    seuss
# error for    selektmail
# error for    chevelle
# error for    saharan
# error for    rottwieler
# error for    croatian
# error for    lombardi
# error for    lucchetti
# error for    purina
# error for    earnhardt
# error for    mounty
# error for    larkin
# error for    thain
# error for    insulfoam
# error for    kuala
# error for    lumpar
# error for    smithsonian
# error for    dses
# error for    nintendos
# error for    racedog
# error for    respol
# error for    matulog
# error for    hansa
# error for    lotos
# error for    farmosa
# error for    gleati
# error for    savoie
# error for    lettere
# error for    allianz
# error for    3ny
# error for    equadorian
# error for    zoey
# error for    dashnell
# error for    stratego
# error for    doneley
# error for    sziget
# error for    vons
# error for    russel
# error for    patricks
# error for    zedong
# error for    ourense
# error for    carpintaria
# error for    calbi
# error for    sorvete
# error for    nicolau
# error for    sorvette
# 18289

# %%
M.shape
# Out:
# (18289, 300)

# %%
#pad token '_' has been dealt seperately because it might have affected the word2vec training if used earlier
vec.word_index['_'] = 0 #adding 0 for padding
vec.index_word[0] = '_'
M = np.vstack((np.zeros((1,300)),M)) #putting zero vector at 0th row for padding
seq = vec.texts_to_sequences(df['tokens_pad']) #converting tokens to corrosponding indicies so that they can be
                                               #they can be used for mapping by embedding layer during training
seq_vec = np.array(seq).astype('int32')

# %%
df.to_csv(r'/content/drive/My Drive/ImageCap/captions_pros.csv',index=None,header=True) # all further mappings will be as per this csv
np.save('/content/drive/My Drive/ImageCap/embedB.npy',M)
np.save('/content/drive/My Drive/ImageCap/caption_vec.npy',seq_vec)

with open('/content/drive/My Drive/ImageCap/word_ind_map.pkl', 'wb') as f:
  pickle.dump(vec.word_index, f, pickle.HIGHEST_PROTOCOL)

with open('x/ind_word_map.pkl', 'wb') as f:
  pickle.dump(vec.index_word, f, pickle.HIGHEST_PROTOCOL)
